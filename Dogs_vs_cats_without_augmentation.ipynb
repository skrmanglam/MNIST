# %% [markdown]
# <a href="https://colab.research.google.com/github/skrmanglam/MNIST/blob/main/Dogs_vs_cats_without_augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this tutorial, we will discuss how to classify images into pictures of cats or pictures of dogs. We'll build an image classifier using `tf.keras.Sequential` model and load data using `tf.keras.preprocessing.image.ImageDataGenerator`.
#
# ## Specific concepts that will be covered:
# In the process, we will build practical experience and develop intuition around the following concepts
#
# * Building _data input pipelines_ using the `tf.keras.preprocessing.image.ImageDataGenerator` class — How can we efficiently work with data on disk to interface with our model?
# * _Overfitting_ - what is it, how to identify it?
#
# <hr>
#
#
# **Before you begin**
#
# Before running the code in this notebook, reset the runtime by going to **Runtime -> Reset all runtimes** in the menu above. If you have been working through several notebooks, this will help you avoid reaching Colab's memory limits.

# %% [markdown]
# # Importing packages

# %% [markdown]
# Let's start by importing required packages:
#
# *   os — to read files and directory structure
# *   numpy — for some matrix math outside of TensorFlow
# *   matplotlib.pyplot — to plot the graph and display images in our training and validation data

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import matplotlib.pyplot as plt
import numpy as np
import logging
logger= tf.get_logger()
logger.setLevel(logging.ERROR)

# %% [markdown]
# # Data Loading

# %% [markdown]
# To build our image classifier, we begin by downloading the dataset. The dataset we are using is a filtered version of <a href="https://www.kaggle.com/c/dogs-vs-cats/data" target="_blank">Dogs vs. Cats</a> dataset from Kaggle (ultimately, this dataset is provided by Microsoft Research).
#
# In previous Colabs, we've used <a href="https://www.tensorflow.org/datasets" target="_blank">TensorFlow Datasets</a>, which is a very easy and convenient way to use datasets. In this Colab however, we will make use of the class `tf.keras.preprocessing.image.ImageDataGenerator` which will read data from disk. We therefore need to directly download *Dogs vs. Cats* from a URL and unzip it to the Colab filesystem.

# %%
_URL = 'https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip'
zip_dir= tf.keras.utils.get_file('cats_and_dogs_filterted.zip',origin=_URL, extract=True)
# Out:
# Downloading data from https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# 68608000/68606236 [==============================] - 0s 0us/step

# %% [markdown]
# The dataset we have downloaded has the following directory structure.
#
# <pre style="font-size: 10.0pt; font-family: Arial; line-height: 2; letter-spacing: 1.0pt;" >
# <b>cats_and_dogs_filtered</b>
# |__ <b>train</b>
#     |______ <b>cats</b>: [cat.0.jpg, cat.1.jpg, cat.2.jpg ...]
#     |______ <b>dogs</b>: [dog.0.jpg, dog.1.jpg, dog.2.jpg ...]
# |__ <b>validation</b>
#     |______ <b>cats</b>: [cat.2000.jpg, cat.2001.jpg, cat.2002.jpg ...]
#     |______ <b>dogs</b>: [dog.2000.jpg, dog.2001.jpg, dog.2002.jpg ...]
# </pre>
#
# We can list the directories with the following terminal command:

# %%
zip_dir_base = os.path.dirname(zip_dir)
# !find $zip_dir_base -type d -print
# Out:
# /root/.keras/datasets
# /root/.keras/datasets/cats_and_dogs_filtered
# /root/.keras/datasets/cats_and_dogs_filtered/validation
# /root/.keras/datasets/cats_and_dogs_filtered/validation/dogs
# /root/.keras/datasets/cats_and_dogs_filtered/validation/cats
# /root/.keras/datasets/cats_and_dogs_filtered/train
# /root/.keras/datasets/cats_and_dogs_filtered/train/dogs
# /root/.keras/datasets/cats_and_dogs_filtered/train/cats

# %% [markdown]
# We will now assign variables with the proper file path for the training and validation sets.

# %%
base_dir = os.path.join(os.path.dirname(zip_dir),'cats_and_dogs_filtered')
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join( base_dir, 'validation')

train_cats_dir = os.path.join(train_dir, 'cats')  #directory with our training cat pics
train_dogs_dir = os.path.join(train_dir, 'dogs')  #directory with our trainig dog pics
validation_cats_dir = os.path.join(validation_dir, 'cats') #directory with our validation cat pics
validation_dogs_dir = os.path.join(validation_dir, 'dogs') #directory with our validation dog pics

# %% [markdown]
# ### Understanding our data

# %% [markdown]
# Let's look at how many cats and dogs images we have in our training and validation directory

# %%
num_cats_tr = len(os.listdir(train_cats_dir))
num_dogs_tr = len(os.listdir(train_dogs_dir))

num_cats_val = len(os.listdir(validation_cats_dir))
num_dogs_val = len(os.listdir(validation_dogs_dir))

total_train = num_cats_tr + num_dogs_tr
total_val = num_cats_val + num_dogs_val

# %%
print('total training cat images:', num_cats_tr)
print('total training dog image', num_dogs_tr)

print('total validation cat images:', num_cats_val)
print('total validation dog images:', num_dogs_val)
print("--")
print("Total training images:", total_train)
print("Total validation images:", total_val)
# Out:
# total training cat images: 1000
# total training dog image 1000
# total validation cat images: 500
# total validation dog images: 500
# --
# Total training images: 2000
# Total validation images: 1000

# %% [markdown]
# # Setting Model Parameters

# %% [markdown]
# For convinience, we'll set up variables that will be used later while pre-processing our dataset and training our network.

# %%
BATCH_SIZE = 100 # Number of training examples to process before updating our models variables
IMG_SHAPE = 150 # Our training data consists of images with width of 150 pixels and height of 150 pixels

# %% [markdown]
# # Data Preparation

# %% [markdown]
# Images must be formatted into appropriately pre-processed floating point tensors before being fed into the network. The steps involved in preparing these images are:
#
# 1. Read images from the disk
# 2. Decode contents of these images and convert it into proper grid format as per their RGB content
# 3. Convert them into floating point tensors
# 4. Rescale the tensors from values between 0 and 255 to values between 0 and 1, as neural networks prefer to deal with small input values.
#
# Fortunately, all these tasks can be done using the class **tf.keras.preprocessing.image.ImageDataGenerator**.
#
# We can set this up in a couple of lines of code.

# %%
train_image_generator = ImageDataGenerator(rescale=1./255) #Generator for our training data
validation_image_generator = ImageDataGenerator(rescale=1./255) #Generator for our validation data

# %% [markdown]
# After defining our generators for training and validation images, **flow_from_directory** method will load images from the disk, apply rescaling, and resize them using single line of code.

# %%
train_data_gen = train_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                           directory=train_dir,
                                                           shuffle=True,
                                                           target_size=(IMG_SHAPE,IMG_SHAPE), #(150,150)
                                                           class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
val_data_gen = validation_image_generator.flow_from_directory(batch_size=BATCH_SIZE,
                                                              directory=validation_dir,
                                                              shuffle=False,
                                                              target_size=(IMG_SHAPE,IMG_SHAPE), #(150,150)
                                                              class_mode='binary')
# Out:
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# ### Visualizing Training images

# %% [markdown]
# We can visualize our training images by getting a batch of images from the training generator, and then plotting a few of them using `matplotlib`.

# %%
sample_training_images, _=next(train_data_gen)

# %% [markdown]
# The `next` function returns a batch from the dataset. One batch is a tuple of (*many images*, *many labels*). For right now, we're discarding the labels because we just want to look at the images.

# %%
# This function will plot images in the form of a grid with 1 row and 5 columns where image are palced in each column.
def plotImages(images_arr):
  fig, axes = plt.subplots(1, 5, figsize=(20,20))
  axes = axes.flatten()
  for img, ax in zip(images_arr, axes):
    ax.imshow(img)
  plt.tight_layout()
  plt.show()

# %%
plotImages(sample_training_images[:5]) # Plot images 0-4

# %% [markdown]
# # Model Creation

# %% [markdown]
# ## Define the model
#
# The model consists of four convolution blocks with a max pool layer in each of them. Then we have a fully connected layer with 512 units, with a `relu` activation function. The model will output class probabilities for two classes — dogs and cats — using `softmax`.

# %%
model = tf.keras.models.Sequential([
        tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(150,150,3)),
        tf.keras.layers.MaxPooling2D(2,2),

        tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),

        tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
        tf.keras.layers.MaxPooling2D(2,2),

        tf.keras.layers.Conv2D(128, (3,3), activation= 'relu'),
        tf.keras.layers.MaxPooling2D(2,2),

        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(2)
])

# %% [markdown]
# ### Compile the model
#
# As usual, we will use the `adam` optimizer. Since we output a softmax categorization, we'll use `sparse_categorical_crossentropy` as the loss function. We would also like to look at training and validation accuracy on each epoch as we train our network, so we are passing in the metrics argument.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Model Summary
#
# Let's look at all the layers of our network using **summary** method.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3211776
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 3,453,634
# Trainable params: 3,453,634
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %% [markdown]
# It's time we train our network.
#
# Since our batches are coming from a generator (`ImageDataGenerator`), we'll use `fit_generator` instead of `fit`.

# %%
EPOCHS = 100
history = model.fit_generator(
    train_data_gen,
    steps_per_epoch= int(np.ceil(total_train/float(BATCH_SIZE))),
    epochs = EPOCHS,
    validation_data= val_data_gen,
    validation_steps= int(np.ceil(total_val/float(BATCH_SIZE)))
)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1940: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 20/20 [==============================] - 41s 438ms/step - loss: 0.7028 - accuracy: 0.5225 - val_loss: 0.6865 - val_accuracy: 0.5000
# Epoch 2/100
# 20/20 [==============================] - 8s 412ms/step - loss: 0.6810 - accuracy: 0.5375 - val_loss: 0.6543 - val_accuracy: 0.5850
# Epoch 3/100
# 20/20 [==============================] - 8s 415ms/step - loss: 0.6635 - accuracy: 0.5680 - val_loss: 0.6452 - val_accuracy: 0.6090
# Epoch 4/100
# 20/20 [==============================] - 8s 405ms/step - loss: 0.6152 - accuracy: 0.6495 - val_loss: 0.6118 - val_accuracy: 0.6560
# Epoch 5/100
# 20/20 [==============================] - 8s 395ms/step - loss: 0.5729 - accuracy: 0.6940 - val_loss: 0.6340 - val_accuracy: 0.6660
# Epoch 6/100
# 20/20 [==============================] - 8s 393ms/step - loss: 0.5351 - accuracy: 0.7330 - val_loss: 0.5795 - val_accuracy: 0.6930
# Epoch 7/100
# 20/20 [==============================] - 8s 427ms/step - loss: 0.5197 - accuracy: 0.7340 - val_loss: 0.5674 - val_accuracy: 0.7130
# Epoch 8/100
# 20/20 [==============================] - 8s 425ms/step - loss: 0.4664 - accuracy: 0.7745 - val_loss: 0.5554 - val_accuracy: 0.7200
# Epoch 9/100
# 20/20 [==============================] - 9s 429ms/step - loss: 0.4306 - accuracy: 0.7935 - val_loss: 0.5732 - val_accuracy: 0.7300
# Epoch 10/100
# 20/20 [==============================] - 8s 402ms/step - loss: 0.4042 - accuracy: 0.8170 - val_loss: 0.5915 - val_accuracy: 0.7200
# Epoch 11/100
# 20/20 [==============================] - 8s 399ms/step - loss: 0.3658 - accuracy: 0.8440 - val_loss: 0.6005 - val_accuracy: 0.7390
# Epoch 12/100
# 20/20 [==============================] - 8s 402ms/step - loss: 0.3443 - accuracy: 0.8480 - val_loss: 0.5665 - val_accuracy: 0.7500
# Epoch 13/100
# 20/20 [==============================] - 8s 398ms/step - loss: 0.2893 - accuracy: 0.8860 - val_loss: 0.6983 - val_accuracy: 0.7330
# Epoch 14/100
# 20/20 [==============================] - 8s 398ms/step - loss: 0.2351 - accuracy: 0.9040 - val_loss: 0.6333 - val_accuracy: 0.7450
# Epoch 15/100
# 20/20 [==============================] - 8s 425ms/step - loss: 0.1894 - accuracy: 0.9260 - val_loss: 0.7013 - val_accuracy: 0.7430
# Epoch 16/100
# 20/20 [==============================] - 8s 423ms/step - loss: 0.1632 - accuracy: 0.9310 - val_loss: 0.8708 - val_accuracy: 0.7220
# Epoch 17/100
# 20/20 [==============================] - 8s 425ms/step - loss: 0.1334 - accuracy: 0.9535 - val_loss: 0.7670 - val_accuracy: 0.7470
# Epoch 18/100
# 20/20 [==============================] - 8s 394ms/step - loss: 0.0884 - accuracy: 0.9750 - val_loss: 0.9029 - val_accuracy: 0.7650
# Epoch 19/100
# 20/20 [==============================] - 8s 426ms/step - loss: 0.0850 - accuracy: 0.9635 - val_loss: 0.9114 - val_accuracy: 0.7480
# Epoch 20/100
# 20/20 [==============================] - 8s 425ms/step - loss: 0.0562 - accuracy: 0.9825 - val_loss: 1.0660 - val_accuracy: 0.7500
# Epoch 21/100
# 20/20 [==============================] - 8s 422ms/step - loss: 0.0421 - accuracy: 0.9835 - val_loss: 1.3023 - val_accuracy: 0.7430
# Epoch 22/100
# 20/20 [==============================] - 8s 402ms/step - loss: 0.0338 - accuracy: 0.9910 - val_loss: 1.1913 - val_accuracy: 0.7480
# Epoch 23/100
# 20/20 [==============================] - 8s 403ms/step - loss: 0.0168 - accuracy: 0.9960 - val_loss: 1.3562 - val_accuracy: 0.7390
# Epoch 24/100
# 20/20 [==============================] - 8s 398ms/step - loss: 0.0427 - accuracy: 0.9825 - val_loss: 1.1903 - val_accuracy: 0.7410
# Epoch 25/100
# 20/20 [==============================] - 8s 398ms/step - loss: 0.0559 - accuracy: 0.9790 - val_loss: 1.1798 - val_accuracy: 0.7480
# Epoch 26/100
# 20/20 [==============================] - 8s 398ms/step - loss: 0.0440 - accuracy: 0.9860 - val_loss: 1.4024 - val_accuracy: 0.7370
# Epoch 27/100
# 20/20 [==============================] - 8s 423ms/step - loss: 0.0351 - accuracy: 0.9880 - val_loss: 1.3462 - val_accuracy: 0.7330
# Epoch 28/100
# 20/20 [==============================] - 8s 425ms/step - loss: 0.0277 - accuracy: 0.9910 - val_loss: 1.3705 - val_accuracy: 0.7420
# Epoch 29/100
# 20/20 [==============================] - 8s 427ms/step - loss: 0.0089 - accuracy: 0.9970 - val_loss: 1.5089 - val_accuracy: 0.7450
# Epoch 30/100
# 20/20 [==============================] - 8s 404ms/step - loss: 0.0082 - accuracy: 0.9975 - val_loss: 1.5658 - val_accuracy: 0.7500
# Epoch 31/100
# 20/20 [==============================] - 8s 402ms/step - loss: 0.0051 - accuracy: 0.9985 - val_loss: 1.6759 - val_accuracy: 0.7530
# Epoch 32/100
# 20/20 [==============================] - 8s 400ms/step - loss: 0.0027 - accuracy: 0.9995 - val_loss: 1.7783 - val_accuracy: 0.7470
# Epoch 33/100
# 20/20 [==============================] - 8s 400ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 1.8421 - val_accuracy: 0.7500
# Epoch 34/100
# 20/20 [==============================] - 8s 400ms/step - loss: 9.2625e-04 - accuracy: 1.0000 - val_loss: 1.8127 - val_accuracy: 0.7440
# Epoch 35/100
# 20/20 [==============================] - 8s 421ms/step - loss: 4.1338e-04 - accuracy: 1.0000 - val_loss: 1.8250 - val_accuracy: 0.7500
# Epoch 36/100
# 20/20 [==============================] - 9s 430ms/step - loss: 2.8155e-04 - accuracy: 1.0000 - val_loss: 1.8349 - val_accuracy: 0.7540
# Epoch 37/100
# 20/20 [==============================] - 8s 426ms/step - loss: 2.2824e-04 - accuracy: 1.0000 - val_loss: 1.8481 - val_accuracy: 0.7560
# Epoch 38/100
# 20/20 [==============================] - 8s 406ms/step - loss: 2.0034e-04 - accuracy: 1.0000 - val_loss: 1.8629 - val_accuracy: 0.7580
# Epoch 39/100
# 20/20 [==============================] - 8s 403ms/step - loss: 1.7917e-04 - accuracy: 1.0000 - val_loss: 1.8795 - val_accuracy: 0.7550
# Epoch 40/100
# 20/20 [==============================] - 8s 399ms/step - loss: 1.6305e-04 - accuracy: 1.0000 - val_loss: 1.8957 - val_accuracy: 0.7560
# Epoch 41/100
# 20/20 [==============================] - 8s 405ms/step - loss: 1.4836e-04 - accuracy: 1.0000 - val_loss: 1.9062 - val_accuracy: 0.7580
# Epoch 42/100
# 20/20 [==============================] - 8s 398ms/step - loss: 1.3520e-04 - accuracy: 1.0000 - val_loss: 1.9207 - val_accuracy: 0.7560
# Epoch 43/100
# 20/20 [==============================] - 8s 427ms/step - loss: 1.2532e-04 - accuracy: 1.0000 - val_loss: 1.9311 - val_accuracy: 0.7580
# Epoch 44/100
# 20/20 [==============================] - 8s 426ms/step - loss: 1.1720e-04 - accuracy: 1.0000 - val_loss: 1.9424 - val_accuracy: 0.7580
# Epoch 45/100
# 20/20 [==============================] - 8s 427ms/step - loss: 1.0883e-04 - accuracy: 1.0000 - val_loss: 1.9530 - val_accuracy: 0.7580
# Epoch 46/100
# 20/20 [==============================] - 8s 400ms/step - loss: 1.0215e-04 - accuracy: 1.0000 - val_loss: 1.9651 - val_accuracy: 0.7570
# Epoch 47/100
# 20/20 [==============================] - 8s 402ms/step - loss: 9.5906e-05 - accuracy: 1.0000 - val_loss: 1.9749 - val_accuracy: 0.7590
# Epoch 48/100
# 20/20 [==============================] - 8s 399ms/step - loss: 8.9776e-05 - accuracy: 1.0000 - val_loss: 1.9876 - val_accuracy: 0.7590
# Epoch 49/100
# 20/20 [==============================] - 8s 398ms/step - loss: 8.4250e-05 - accuracy: 1.0000 - val_loss: 2.0000 - val_accuracy: 0.7590
# Epoch 50/100
# 20/20 [==============================] - 8s 401ms/step - loss: 7.8025e-05 - accuracy: 1.0000 - val_loss: 2.0228 - val_accuracy: 0.7580
# Epoch 51/100
# 20/20 [==============================] - 8s 427ms/step - loss: 7.0609e-05 - accuracy: 1.0000 - val_loss: 2.0621 - val_accuracy: 0.7630
# Epoch 52/100
# 20/20 [==============================] - 8s 427ms/step - loss: 6.1143e-05 - accuracy: 1.0000 - val_loss: 2.0896 - val_accuracy: 0.7630
# Epoch 53/100
# 20/20 [==============================] - 8s 428ms/step - loss: 5.5731e-05 - accuracy: 1.0000 - val_loss: 2.1398 - val_accuracy: 0.7620
# Epoch 54/100
# 20/20 [==============================] - 8s 402ms/step - loss: 4.7804e-05 - accuracy: 1.0000 - val_loss: 2.1774 - val_accuracy: 0.7610
# Epoch 55/100
# 20/20 [==============================] - 8s 428ms/step - loss: 4.4009e-05 - accuracy: 1.0000 - val_loss: 2.1823 - val_accuracy: 0.7610
# Epoch 56/100
# 20/20 [==============================] - 8s 427ms/step - loss: 3.8230e-05 - accuracy: 1.0000 - val_loss: 2.2157 - val_accuracy: 0.7630
# Epoch 57/100
# 20/20 [==============================] - 8s 427ms/step - loss: 3.4563e-05 - accuracy: 1.0000 - val_loss: 2.2461 - val_accuracy: 0.7600
# Epoch 58/100
# 20/20 [==============================] - 8s 399ms/step - loss: 3.0005e-05 - accuracy: 1.0000 - val_loss: 2.2749 - val_accuracy: 0.7570
# Epoch 59/100
# 20/20 [==============================] - 8s 409ms/step - loss: 2.7367e-05 - accuracy: 1.0000 - val_loss: 2.2871 - val_accuracy: 0.7600
# Epoch 60/100
# 20/20 [==============================] - 8s 400ms/step - loss: 2.4403e-05 - accuracy: 1.0000 - val_loss: 2.3198 - val_accuracy: 0.7580
# Epoch 61/100
# 20/20 [==============================] - 8s 403ms/step - loss: 2.1711e-05 - accuracy: 1.0000 - val_loss: 2.3241 - val_accuracy: 0.7570
# Epoch 62/100
# 20/20 [==============================] - 8s 402ms/step - loss: 1.9606e-05 - accuracy: 1.0000 - val_loss: 2.3636 - val_accuracy: 0.7600
# Epoch 63/100
# 20/20 [==============================] - 8s 425ms/step - loss: 1.8006e-05 - accuracy: 1.0000 - val_loss: 2.3916 - val_accuracy: 0.7580
# Epoch 64/100
# 20/20 [==============================] - 8s 424ms/step - loss: 1.6473e-05 - accuracy: 1.0000 - val_loss: 2.3842 - val_accuracy: 0.7590
# Epoch 65/100
# 20/20 [==============================] - 9s 429ms/step - loss: 1.4924e-05 - accuracy: 1.0000 - val_loss: 2.4180 - val_accuracy: 0.7560
# Epoch 66/100
# 20/20 [==============================] - 8s 399ms/step - loss: 1.3733e-05 - accuracy: 1.0000 - val_loss: 2.4221 - val_accuracy: 0.7570
# Epoch 67/100
# 20/20 [==============================] - 8s 405ms/step - loss: 1.2734e-05 - accuracy: 1.0000 - val_loss: 2.4494 - val_accuracy: 0.7580
# Epoch 68/100
# 20/20 [==============================] - 8s 405ms/step - loss: 1.1771e-05 - accuracy: 1.0000 - val_loss: 2.4589 - val_accuracy: 0.7570
# Epoch 69/100
# 20/20 [==============================] - 8s 401ms/step - loss: 1.1030e-05 - accuracy: 1.0000 - val_loss: 2.4785 - val_accuracy: 0.7490
# Epoch 70/100
# 20/20 [==============================] - 8s 403ms/step - loss: 1.0170e-05 - accuracy: 1.0000 - val_loss: 2.4655 - val_accuracy: 0.7520
# Epoch 71/100
# 20/20 [==============================] - 8s 426ms/step - loss: 9.5499e-06 - accuracy: 1.0000 - val_loss: 2.4902 - val_accuracy: 0.7540
# Epoch 72/100
# 20/20 [==============================] - 8s 425ms/step - loss: 8.6111e-06 - accuracy: 1.0000 - val_loss: 2.5193 - val_accuracy: 0.7550
# Epoch 73/100
# 20/20 [==============================] - 8s 426ms/step - loss: 8.2639e-06 - accuracy: 1.0000 - val_loss: 2.5131 - val_accuracy: 0.7530
# Epoch 74/100
# 20/20 [==============================] - 8s 401ms/step - loss: 7.6073e-06 - accuracy: 1.0000 - val_loss: 2.5341 - val_accuracy: 0.7540
# Epoch 75/100
# 20/20 [==============================] - 8s 398ms/step - loss: 7.1129e-06 - accuracy: 1.0000 - val_loss: 2.5440 - val_accuracy: 0.7530
# Epoch 76/100
# 20/20 [==============================] - 8s 401ms/step - loss: 6.7689e-06 - accuracy: 1.0000 - val_loss: 2.5462 - val_accuracy: 0.7560
# Epoch 77/100
# 20/20 [==============================] - 8s 400ms/step - loss: 6.3950e-06 - accuracy: 1.0000 - val_loss: 2.5597 - val_accuracy: 0.7540
# Epoch 78/100
# 20/20 [==============================] - 8s 411ms/step - loss: 6.1421e-06 - accuracy: 1.0000 - val_loss: 2.5758 - val_accuracy: 0.7540
# Epoch 79/100
# 20/20 [==============================] - 8s 428ms/step - loss: 5.7149e-06 - accuracy: 1.0000 - val_loss: 2.5804 - val_accuracy: 0.7550
# Epoch 80/100
# 20/20 [==============================] - 9s 429ms/step - loss: 5.4059e-06 - accuracy: 1.0000 - val_loss: 2.5819 - val_accuracy: 0.7560
# Epoch 81/100
# 20/20 [==============================] - 9s 430ms/step - loss: 5.1690e-06 - accuracy: 1.0000 - val_loss: 2.5995 - val_accuracy: 0.7540
# Epoch 82/100
# 20/20 [==============================] - 8s 409ms/step - loss: 4.8718e-06 - accuracy: 1.0000 - val_loss: 2.6106 - val_accuracy: 0.7540
# Epoch 83/100
# 20/20 [==============================] - 8s 400ms/step - loss: 4.6517e-06 - accuracy: 1.0000 - val_loss: 2.6162 - val_accuracy: 0.7550
# Epoch 84/100
# 20/20 [==============================] - 8s 398ms/step - loss: 4.4999e-06 - accuracy: 1.0000 - val_loss: 2.6246 - val_accuracy: 0.7550
# Epoch 85/100
# 20/20 [==============================] - 8s 398ms/step - loss: 4.3135e-06 - accuracy: 1.0000 - val_loss: 2.6308 - val_accuracy: 0.7530
# Epoch 86/100
# 20/20 [==============================] - 8s 396ms/step - loss: 4.1059e-06 - accuracy: 1.0000 - val_loss: 2.6452 - val_accuracy: 0.7550
# Epoch 87/100
# 20/20 [==============================] - 8s 416ms/step - loss: 3.8783e-06 - accuracy: 1.0000 - val_loss: 2.6464 - val_accuracy: 0.7550
# Epoch 88/100
# 20/20 [==============================] - 8s 422ms/step - loss: 3.6878e-06 - accuracy: 1.0000 - val_loss: 2.6606 - val_accuracy: 0.7520
# Epoch 89/100
# 20/20 [==============================] - 8s 423ms/step - loss: 3.8107e-06 - accuracy: 1.0000 - val_loss: 2.6599 - val_accuracy: 0.7560
# Epoch 90/100
# 20/20 [==============================] - 8s 406ms/step - loss: 3.4145e-06 - accuracy: 1.0000 - val_loss: 2.6673 - val_accuracy: 0.7570
# Epoch 91/100
# 20/20 [==============================] - 8s 420ms/step - loss: 3.3218e-06 - accuracy: 1.0000 - val_loss: 2.6784 - val_accuracy: 0.7560
# Epoch 92/100
# 20/20 [==============================] - 8s 425ms/step - loss: 3.2454e-06 - accuracy: 1.0000 - val_loss: 2.6824 - val_accuracy: 0.7560
# Epoch 93/100
# 20/20 [==============================] - 8s 424ms/step - loss: 3.0629e-06 - accuracy: 1.0000 - val_loss: 2.6928 - val_accuracy: 0.7590
# Epoch 94/100
# 20/20 [==============================] - 8s 402ms/step - loss: 2.9484e-06 - accuracy: 1.0000 - val_loss: 2.6991 - val_accuracy: 0.7580
# Epoch 95/100
# 20/20 [==============================] - 8s 402ms/step - loss: 2.7640e-06 - accuracy: 1.0000 - val_loss: 2.7077 - val_accuracy: 0.7570
# Epoch 96/100
# 20/20 [==============================] - 8s 397ms/step - loss: 2.7817e-06 - accuracy: 1.0000 - val_loss: 2.7210 - val_accuracy: 0.7510
# Epoch 97/100
# 20/20 [==============================] - 8s 396ms/step - loss: 2.7047e-06 - accuracy: 1.0000 - val_loss: 2.7182 - val_accuracy: 0.7570
# Epoch 98/100
# 20/20 [==============================] - 8s 398ms/step - loss: 2.4886e-06 - accuracy: 1.0000 - val_loss: 2.7243 - val_accuracy: 0.7580
# Epoch 99/100
# 20/20 [==============================] - 8s 417ms/step - loss: 2.4018e-06 - accuracy: 1.0000 - val_loss: 2.7318 - val_accuracy: 0.7600
# Epoch 100/100
# 20/20 [==============================] - 9s 428ms/step - loss: 2.3095e-06 - accuracy: 1.0000 - val_loss: 2.7377 - val_accuracy: 0.7570

# %% [markdown]
# ### Visualizing results of the training

# %% [markdown]
# We'll now visualize the results we get after training our network.

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(EPOCHS)

plt.figure(figsize=(8,8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label= 'Training Loss')
plt.plot(epochs_range, val_loss, label= 'Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.savefig('./foo.png')
plt.show()
